# %% [markdown]
# ![Captura de pantalla 2023-08-02 a la(s) 1.06.39 p.m..png](data:image/png;base64,...)

# %% [markdown]
# # Librerias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Funciones KS

# %%
from funciones_KS_test import*

#Funciones dentro del archivo funciones_KS_test.py:

# KS_test_normal(data,media=0,desvesta=1): Performs a KS test for a normal probability distribution
# KS_test_lognormal(data,media=0,desvesta=1): Performs a KS test for a lognormal probability distribution.
# KS_test_exponential(data,tasa=1): Performs a KS test for an exponential probability distribution.
# KS_test_uniform(data,minimo=0,maximo=1): Performs a KS test for a uniform probability distribution.
# KS_test_triangular(data,minimo=0,maximo=1,moda=0.5): Performs a KS test for a triangular probability distribution.
# KS_test_gamma(data,media=1,varianza=1): Performs a KS test for a gamma probability distribution.
# KS_test_weibull(data,forma=1,escala=1): Performs a KS test for a Weibull probability distribution.

# PP_plot_custom(data,function): PP plot with a custom probability distribution.
# KS_custom(data,function): Performs a KS test for a custom probability distribution.

# %% [markdown]
# # Importar data

# %% [markdown]
# Importar datos con el archivo de excel cargado a GoogleColab
#
# """NOTA: Cambie el nombre de acuerdo con el nombre del archivo de Excel:"""

# %%
# Se importan los datos del archivo de Excel utilizando el paquete Pandas.
df = pd.read_excel('Datos_TEA.xlsx')
data = np.array(df).flatten()
data

# %% [markdown]
# ## Prueba K-S para varias distribuciones

# %% [markdown]
# **Prueba KS para una distribución normal**

# %%
KS_test_normal(data,media=0.3298,desvesta=0.3178)

# %% [markdown]
# **Prueba KS para una distribución lognormal**

# %%
KS_test_lognormal(data,media=-1.7488,desvesta=1.3811)

# %% [markdown]
# **Prueba KS para una distribución exponencial**

# %%
KS_test_exponential(data,tasa=3.0317)

# %% [markdown]
# **Prueba KS para una distribución uniforme**

# %%
KS_test_uniform(data,minimo=0.003,maximo=1.49)

# %% [markdown]
# **Prueba KS para una distribución triangular**

# %%
KS_test_triangular(data,minimo=0.003,maximo=1.49,moda=0.19)

# %% [markdown]
# **Prueba KS para una distribución gamma**

# %%
KS_test_gamma(data,media=0.3298,varianza=0.1)

# %% [markdown]
# **Prueba KS para una distribución weibull**

# %%
KS_test_weibull(data,forma=0.9595,escala=0.3241)
